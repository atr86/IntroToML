# %%
import numpy as np
import sympy as sp
from sympy import *
init_printing(use_unicode=True)

# %%
#m = int(input("Enter no of rows"))
#n = int(input("Enter no of columns"))
m=4
n=4
arr = [[0 for _ in range(n)] for _ in range(m)]
arr=[[1,1,1,1],[2,2,4,4],[5,5,7,7],[1,4,6,8]]
print(arr)

for i in range(m):
    for j in range(n):
        print(arr[i][j],end=" ")
    print()
# Out:
# [[1, 1, 1, 1], [2, 2, 4, 4], [5, 5, 7, 7], [1, 4, 6, 8]]
# 1 1 1 1
# 2 2 4 4
# 5 5 7 7
# 1 4 6 8

# %%
M= Matrix(arr)
display(M)
M=M.rref()[0]
display(M)
# Out:
# ⎡1  1  1  1⎤
# ⎢          ⎥
# ⎢2  2  4  4⎥
# ⎢          ⎥
# ⎢5  5  7  7⎥
# ⎢          ⎥
# ⎣1  4  6  8⎦
# ⎡1  0  0  -2/3⎤
# ⎢             ⎥
# ⎢0  1  0  2/3 ⎥
# ⎢             ⎥
# ⎢0  0  1   1  ⎥
# ⎢             ⎥
# ⎣0  0  0   0  ⎦

# %%
zero=0
one=0
r=0
a=np.array(M)
b=[0 for _ in range(n)]
for j in range(n):
  zero=0
  one=0
  for i in range(m):
       if a[i][j]==0:
         zero=zero+1
       if a[i][j]==1:
         one=one+1
  if one==1 and zero==m-1:
     b[j]=1
     r+=1
  else:
     b[j]=0
print(b)#WHICH COLUMNS CONTAIN PIVOT AND WHICH DOES NOT
print("Rank is",r)
# Out:
# [1, 1, 1, 0]
# Rank is 3

# %%
count=0
print("The Row Spaces are ")
for i in range(r):
    print(arr[i])
# Out:
# The Row Spaces are
# [1, 1, 1, 1]
# [2, 2, 4, 4]
# [5, 5, 7, 7]

# %%
k=0# gets to next column where F is there
l=0# gets to next row where F is there
N=[[0 for _ in range(n-r)] for _ in range(n)] #NULL SPACE
for j in range(n-r):
  while b[k]!=0:
        k+=1
  for i in range(n):
      if b[i]==1:
            N[i][j]=-a[l][k]
            l+=1
      else:
            if (i==k):
               N[i][j]=1
            else:
               N[i][j]=0
  k=0
  l=0
print(N)
# Out:
# [[2/3], [-2/3], [-1], [1]]
